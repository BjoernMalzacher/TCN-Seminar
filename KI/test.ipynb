# %%
# !pip install -q kokoro>=0.9.2 soundfile
# Out:
# ^C

# %%
pip install --upgrade transformers scipy
# Out:
# Collecting transformers
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: scipy in /home/malzacher/miniconda3/lib/python3.12/site-packages (1.15.2)
# Collecting scipy
#   Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: filelock in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: tqdm>=4.27 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from requests->transformers) (2025.11.12)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 544.8 kB/s eta 0:00:0000:0100:01
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 569.0 kB/s eta 0:00:00:--:--
# Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 511.6 kB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 502.1 kB/s eta 0:00:0000:0100:03
# Using cached regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Installing collected packages: scipy, safetensors, regex, hf-xet, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:━━━━━━━━━━━━━━━━━━ 0/7 [scipy]
#       Successfully uninstalled scipy-1.15.2━ 0/7 [scipy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [transformers] [transformers]ub]
# Successfully installed hf-xet-1.2.0 huggingface-hub-0.36.0 regex-2025.11.3 safetensors-0.7.0 scipy-1.16.3 tokenizers-0.22.1 transformers-4.57.3
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### https://huggingface.co/suno/bark

# %%
from transformers import pipeline
import scipy

# %%
synthesiser = pipeline("text-to-speech", "suno/bark")

speech = synthesiser("We have been lost.", forward_params={"do_sample": True})

scipy.io.wavfile.write("bark_out.wav", rate=speech["sampling_rate"], data=speech["audio"])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.49G [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:626, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     624     progress.update(progress_bytes)
# --> 626 download_files(
#     627     xet_download_info,
#     628     endpoint=connection_info.endpoint,
#     629     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     630     token_refresher=token_refresher,
#     631     progress_updater=[progress_updater],
#     632 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 synthesiser = pipeline("text-to-speech", "suno/bark")
#       3 speech = synthesiser("We have been lost.", forward_params={"do_sample": True})
#       5 scipy.io.wavfile.write("bark_out.wav", rate=speech["sampling_rate"], data=speech["audio"])
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/pipelines/__init__.py:1027, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1025 if isinstance(model, str) or framework is None:
#    1026     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1027     framework, model = infer_framework_load_model(
#    1028         adapter_path if adapter_path is not None else model,
#    1029         model_classes=model_classes,
#    1030         config=config,
#    1031         framework=framework,
#    1032         task=task,
#    1033         **hub_kwargs,
#    1034         **model_kwargs,
#    1035     )
#    1037 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1039 # Check which preprocessing classes the pipeline uses
#    1040 # None values indicate optional classes that the pipeline can run without, we don't raise errors if loading fails
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/pipelines/base.py:293, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     287     logger.warning(
#     288         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     289         "Trying to load the model with Tensorflow."
#     290     )
#     292 try:
# --> 293     model = model_class.from_pretrained(model, **kwargs)
#     294     if hasattr(model, "eval"):
#     295         model = model.eval()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/modeling_utils.py:277, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     275 old_dtype = torch.get_default_dtype()
#     276 try:
# --> 277     return func(*args, **kwargs)
#     278 finally:
#     279     torch.set_default_dtype(old_dtype)
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/modeling_utils.py:4900, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4890 if (
#    4891     gguf_file
#    4892     and device_map is not None
#    4893     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4894 ):
#    4895     raise RuntimeError(
#    4896         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4897         "loaded from GGUF files."
#    4898     )
# -> 4900 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4901     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4902     subfolder=subfolder,
#    4903     variant=variant,
#    4904     gguf_file=gguf_file,
#    4905     from_tf=from_tf,
#    4906     from_flax=from_flax,
#    4907     use_safetensors=use_safetensors,
#    4908     cache_dir=cache_dir,
#    4909     force_download=force_download,
#    4910     proxies=proxies,
#    4911     local_files_only=local_files_only,
#    4912     token=token,
#    4913     user_agent=user_agent,
#    4914     revision=revision,
#    4915     commit_hash=commit_hash,
#    4916     is_remote_code=cls._auto_class is not None,
#    4917     transformers_explicit_filename=transformers_explicit_filename,
#    4918 )
#    4920 is_sharded = sharded_metadata is not None
#    4921 is_quantized = hf_quantizer is not None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/modeling_utils.py:1066, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1063     else:
#    1064         # This repo has no safetensors file of any kind, we switch to PyTorch.
#    1065         filename = _add_variant(WEIGHTS_NAME, variant)
# -> 1066         resolved_archive_file = cached_file(
#    1067             pretrained_model_name_or_path, filename, **cached_file_kwargs
#    1068         )
#    1069 if resolved_archive_file is None and filename == _add_variant(WEIGHTS_NAME, variant):
#    1070     # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#    1071     resolved_archive_file = cached_file(
#    1072         pretrained_model_name_or_path,
#    1073         _add_variant(WEIGHTS_INDEX_NAME, variant),
#    1074         **cached_file_kwargs,
#    1075     )
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)    320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 try:
#     477     if len(full_filenames) == 1:
#     478         # This is slightly better for only 1 file
# --> 479         hf_hub_download(
#     480             path_or_repo_id,
#     481             filenames[0],
#     482             subfolder=None if len(subfolder) == 0 else subfolder,
#     483             repo_type=repo_type,
#     484             revision=revision,
#     485             cache_dir=cache_dir,
#     486             user_agent=user_agent,
#     487             force_download=force_download,
#     488             proxies=proxies,
#     489             resume_download=resume_download,
#     490             token=token,
#     491             local_files_only=local_files_only,
#     492         )
#     493     else:
#     494         snapshot_download(
#     495             path_or_repo_id,
#     496             allow_patterns=full_filenames,
#    (...)    505             local_files_only=local_files_only,
#     506         )
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)   1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1168, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1165 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1167 with WeakFileLock(lock_path):
# -> 1168     _download_to_tmp_and_move(
#    1169         incomplete_path=Path(blob_path + ".incomplete"),
#    1170         destination_path=Path(blob_path),
#    1171         url_to_download=url_to_download,
#    1172         proxies=proxies,
#    1173         headers=headers,
#    1174         expected_size=expected_size,
#    1175         filename=filename,
#    1176         force_download=force_download,
#    1177         etag=etag,
#    1178         xet_file_data=xet_file_data,
#    1179     )
#    1180     if not os.path.exists(pointer_path):
#    1181         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1720, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1718 if xet_file_data is not None and is_xet_available():
#    1719     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1720     xet_get(
#    1721         incomplete_path=incomplete_path,
#    1722         xet_file_data=xet_file_data,
#    1723         headers=headers,
#    1724         expected_size=expected_size,
#    1725         displayed_filename=filename,
#    1726     )
#    1727 else:
#    1728     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:621, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     610     displayed_filename = f"{displayed_filename[:40]}(…)"
#     612 progress_cm = _get_progress_bar_context(
#     613     desc=displayed_filename,
#     614     log_level=logger.getEffectiveLevel(),
#    (...)    618     _tqdm_bar=_tqdm_bar,
#     619 )
# --> 621 with progress_cm as progress:
#     623     def progress_updater(progress_bytes: float):
#     624         progress.update(progress_bytes)
#
# File ~/miniconda3/lib/python3.12/site-packages/tqdm/std.py:1138, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1135 def __enter__(self):
#    1136     return self
# -> 1138 def __exit__(self, exc_type, exc_value, traceback):
#    1139     try:
#    1140         self.close()
#
# KeyboardInterrupt:

# %% [markdown]
# ## https://huggingface.co/openbmb/VoxCPM1.5

# %%
pip install voxcpm
# Out:
# Collecting voxcpm
#   Downloading voxcpm-1.5.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=2.5.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from voxcpm) (2.5.1)
# Collecting torchaudio>=2.5.0 (from voxcpm)
#   Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: transformers>=4.36.2 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from voxcpm) (4.57.3)
# Collecting einops (from voxcpm)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting gradio<6 (from voxcpm)
#   Downloading gradio-5.50.0-py3-none-any.whl.metadata (16 kB)
# Collecting inflect (from voxcpm)
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting addict (from voxcpm)
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting wetext (from voxcpm)
#   Downloading wetext-0.1.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting modelscope>=1.22.0 (from voxcpm)
#   Downloading modelscope-1.33.0-py3-none-any.whl.metadata (43 kB)
# Collecting datasets<4,>=3 (from voxcpm)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface-hub in /home/malzacher/miniconda3/lib/python3.12/site-packages (from voxcpm) (0.36.0)
# Requirement already satisfied: pydantic in /home/malzacher/miniconda3/lib/python3.12/site-packages (from voxcpm) (2.10.3)
# Requirement already satisfied: tqdm in /home/malzacher/miniconda3/lib/python3.12/site-packages (from voxcpm) (4.67.1)
# Collecting simplejson (from voxcpm)
#   Downloading simplejson-3.20.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting sortedcontainers (from voxcpm)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting soundfile (from voxcpm)
#   Using cached soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting funasr (from voxcpm)
#   Downloading funasr-1.2.7-py3-none-any.whl.metadata (32 kB)
# Collecting spaces (from voxcpm)
#   Downloading spaces-0.44.0-py3-none-any.whl.metadata (900 bytes)
# Collecting argbind (from voxcpm)
#   Downloading argbind-0.3.9.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: safetensors in /home/malzacher/miniconda3/lib/python3.12/site-packages (from voxcpm) (0.7.0)
# Requirement already satisfied: filelock in /home/malzacher/miniconda3/lib/python3.12/site-packages (from datasets<4,>=3->voxcpm) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from datasets<4,>=3->voxcpm) (2.0.1)
# Collecting pyarrow>=15.0.0 (from datasets<4,>=3->voxcpm)
#   Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<4,>=3->voxcpm)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/malzacher/miniconda3/lib/python3.12/site-packages (from datasets<4,>=3->voxcpm) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from datasets<4,>=3->voxcpm) (2.32.3)
# Collecting xxhash (from datasets<4,>=3->voxcpm)
#   Downloading xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets<4,>=3->voxcpm)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /home/malzacher/miniconda3/lib/python3.12/site-packages (from datasets<4,>=3->voxcpm) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from datasets<4,>=3->voxcpm) (6.0.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading aiohttp-3.13.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio<6->voxcpm)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting anyio<5.0,>=3.0 (from gradio<6->voxcpm)
#   Using cached anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting brotli>=1.1.0 (from gradio<6->voxcpm)
#   Downloading brotli-1.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio<6->voxcpm)
#   Downloading fastapi-0.124.1-py3-none-any.whl.metadata (30 kB)
# Collecting ffmpy (from gradio<6->voxcpm)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.14.0 (from gradio<6->voxcpm)
#   Downloading gradio_client-1.14.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio<6->voxcpm)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting httpx<1.0,>=0.24.1 (from gradio<6->voxcpm)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jinja2<4.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from gradio<6->voxcpm) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from gradio<6->voxcpm) (3.0.2)
# Collecting orjson~=3.0 (from gradio<6->voxcpm)
#   Downloading orjson-3.11.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: pillow<12.0,>=8.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from gradio<6->voxcpm) (11.1.0)
# Collecting pydub (from gradio<6->voxcpm)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio<6->voxcpm)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.9.3 (from gradio<6->voxcpm)
#   Downloading ruff-0.14.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio<6->voxcpm)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio<6->voxcpm)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio<6->voxcpm)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio<6->voxcpm)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio<6->voxcpm)
#   Downloading typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from gradio<6->voxcpm) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio<6->voxcpm)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting websockets<16.0,>=13.0 (from gradio-client==1.14.0->gradio<6->voxcpm)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: idna>=2.8 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio<6->voxcpm) (3.7)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio<6->voxcpm)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in /home/malzacher/miniconda3/lib/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio<6->voxcpm) (2025.11.12)
# Collecting httpcore==1.* (from httpx<1.0,>=0.24.1->gradio<6->voxcpm)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio<6->voxcpm)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from huggingface-hub->voxcpm) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from pandas->datasets<4,>=3->voxcpm) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from pandas->datasets<4,>=3->voxcpm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from pandas->datasets<4,>=3->voxcpm) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from pydantic->voxcpm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from pydantic->voxcpm) (2.27.1)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio<6->voxcpm)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio<6->voxcpm)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio<6->voxcpm) (13.9.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->voxcpm)
#   Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: setuptools in /home/malzacher/miniconda3/lib/python3.12/site-packages (from modelscope>=1.22.0->voxcpm) (75.8.0)
# Requirement already satisfied: urllib3>=1.26 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from modelscope>=1.22.0->voxcpm) (2.3.0)
# Requirement already satisfied: six>=1.5 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets<4,>=3->voxcpm) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4,>=3->voxcpm) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6->voxcpm) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6->voxcpm) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio<6->voxcpm) (0.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from torch>=2.5.0->voxcpm) (1.13.1)
# Requirement already satisfied: networkx in /home/malzacher/miniconda3/lib/python3.12/site-packages (from torch>=2.5.0->voxcpm) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.5.0->voxcpm) (1.3.0)
# Collecting torch>=2.5.0 (from voxcpm)
#   Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting sympy>=1.13.3 (from torch>=2.5.0->voxcpm)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch>=2.5.0->voxcpm)
#   Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch>=2.5.0->voxcpm)
#   Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: regex!=2019.12.17 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers>=4.36.2->voxcpm) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from transformers>=4.36.2->voxcpm) (0.22.1)
# Collecting docstring-parser (from argbind->voxcpm)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: scipy>=1.4.1 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from funasr->voxcpm) (1.16.3)
# Collecting librosa (from funasr->voxcpm)
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting jamo (from funasr->voxcpm)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting kaldiio>=2.17.0 (from funasr->voxcpm)
#   Downloading kaldiio-2.18.1-py3-none-any.whl.metadata (13 kB)
# Collecting torch-complex (from funasr->voxcpm)
#   Downloading torch_complex-0.4.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting sentencepiece (from funasr->voxcpm)
#   Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting jieba (from funasr->voxcpm)
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 569.7 kB/s eta 0:00:0000:0100:02
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-wpe (from funasr->voxcpm)
#   Downloading pytorch_wpe-0.0.1-py3-none-any.whl.metadata (242 bytes)
# Collecting editdistance>=0.5.2 (from funasr->voxcpm)
#   Downloading editdistance-0.8.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting oss2 (from funasr->voxcpm)
#   Downloading oss2-2.19.1.tar.gz (298 kB)
#   Preparing metadata (setup.py) ... done
# Collecting umap-learn (from funasr->voxcpm)
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# Collecting jaconv (from funasr->voxcpm)
#   Downloading jaconv-0.4.1-py3-none-any.whl.metadata (8.0 kB)
# Collecting hydra-core>=1.3.2 (from funasr->voxcpm)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting tensorboardX (from funasr->voxcpm)
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.3.2->funasr->voxcpm)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.3.2->funasr->voxcpm)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cffi>=1.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from soundfile->voxcpm) (1.17.1)
# Requirement already satisfied: pycparser in /home/malzacher/miniconda3/lib/python3.12/site-packages (from cffi>=1.0->soundfile->voxcpm) (2.21)
# Collecting more_itertools>=8.5.0 (from inflect->voxcpm)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect->voxcpm)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-extensions~=4.0 (from gradio<6->voxcpm)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting audioread>=2.1.9 (from librosa->funasr->voxcpm)
#   Downloading audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numba>=0.51.0 (from librosa->funasr->voxcpm)
#   Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: scikit-learn>=1.1.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from librosa->funasr->voxcpm) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from librosa->funasr->voxcpm) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from librosa->funasr->voxcpm) (5.2.1)
# Collecting pooch>=1.1 (from librosa->funasr->voxcpm)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa->funasr->voxcpm)
#   Downloading soxr-1.0.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting lazy_loader>=0.1 (from librosa->funasr->voxcpm)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa->funasr->voxcpm)
#   Downloading msgpack-1.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.51.0->librosa->funasr->voxcpm)
#   Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from pooch>=1.1->librosa->funasr->voxcpm) (3.10.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from scikit-learn>=1.1.0->librosa->funasr->voxcpm) (3.6.0)
# Collecting crcmod>=1.7 (from oss2->funasr->voxcpm)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome>=3.4.7 (from oss2->funasr->voxcpm)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2->funasr->voxcpm)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2->funasr->voxcpm)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2->funasr->voxcpm)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /home/malzacher/miniconda3/lib/python3.12/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2->funasr->voxcpm) (43.0.3)
# Collecting psutil<6,>=2 (from spaces->voxcpm)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting protobuf>=3.20 (from tensorboardX->funasr->voxcpm)
#   Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pynndescent>=0.5 (from umap-learn->funasr->voxcpm)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting contractions (from wetext->voxcpm)
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting kaldifst (from wetext->voxcpm)
#   Downloading kaldifst-1.7.17-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting textsearch>=0.0.21 (from contractions->wetext->voxcpm)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions->wetext->voxcpm)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions->wetext->voxcpm)
#   Downloading pyahocorasick-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Downloading voxcpm-1.5.0-py3-none-any.whl (58 kB)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading gradio-5.50.0-py3-none-any.whl (63.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 551.9 kB/s eta 0:00:0000:0100:03
# Downloading gradio_client-1.14.0-py3-none-any.whl (325 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading fastapi-0.124.1-py3-none-any.whl (112 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading orjson-3.11.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading typer-0.20.0-py3-none-any.whl (47 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Downloading aiohttp-3.13.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 599.6 kB/s eta 0:00:00a 0:00:01
# Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading brotli-1.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 544.6 kB/s eta 0:00:00a 0:00:01
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading modelscope-1.33.0-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 541.5 kB/s eta 0:00:00a 0:00:01
# Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 493.8 kB/s eta 0:00:0000:0100:03
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.14.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 575.3 kB/s eta 0:00:0000:0100:01
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 569.4 kB/s eta 0:00:00a 0:00:01
# Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
#    ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/899.7 MB 587.0 kB/s eta 0:24:03
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ERROR: Operation cancelled by user
# ^C
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/__main__.py", line 24, in <module>
#     sys.exit(_main())
#              ^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 156, in main
#     with self.main_context():
#          ^^^^^^^^^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/cli/command_context.py", line 19, in main_context
#     with self._main_context:
#          ^^^^^^^^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/contextlib.py", line 610, in __exit__
#     raise exc_details[1]
#   File "/home/malzacher/miniconda3/lib/python3.12/contextlib.py", line 595, in __exit__
#     if cb(*exc_details):
#        ^^^^^^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/utils/temp_dir.py", line 42, in global_tempdir_manager
#     with ExitStack() as stack:
#          ^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/contextlib.py", line 610, in __exit__
#     raise exc_details[1]
#   File "/home/malzacher/miniconda3/lib/python3.12/contextlib.py", line 595, in __exit__
#     if cb(*exc_details):
#        ^^^^^^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/utils/temp_dir.py", line 169, in __exit__
#     self.cleanup()
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/utils/temp_dir.py", line 212, in cleanup
#     rmtree(self._path, ignore_errors=False)
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/utils/retry.py", line 34, in retry_wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/site-packages/pip/_internal/utils/misc.py", line 136, in rmtree
#     shutil.rmtree(dir, onexc=handler)  # type: ignore
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/malzacher/miniconda3/lib/python3.12/shutil.py", line 759, in rmtree
#     _rmtree_safe_fd(stack, onexc)
#   File "/home/malzacher/miniconda3/lib/python3.12/shutil.py", line 698, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# KeyboardInterrupt
# Note: you may need to restart the kernel to use updated packages.

# %%
import soundfile as sf
import numpy as np
from voxcpm import VoxCPM

# %%
model = VoxCPM.from_pretrained("openbmb/VoxCPM1.5")

# Non-streaming
wav = model.generate(
    text="VoxCPM is an innovative end-to-end TTS model from ModelBest, designed to generate highly expressive speech.",
    prompt_wav_path=None,      # optional: path to a prompt speech for voice cloning
    prompt_text=None,          # optional: reference text
    cfg_value=2.0,             # LM guidance on LocDiT, higher for better adherence to the prompt, but maybe worse
    inference_timesteps=3,   # LocDiT inference timesteps, higher for better result, lower for fast speed
    normalize=False,           # enable external TN tool, but will disable native raw text support
    denoise=False,             # enable external Denoise tool, but it may cause some distortion and restrict the sampling rate to 16kHz
    retry_badcase=False,        # enable retrying mode for some bad cases (unstoppable)
    retry_badcase_max_times=3,  # maximum retrying times
    retry_badcase_ratio_threshold=6.0, # maximum length restriction for bad case detection (simple but effective), it could be adjusted for slow pace speech
)

sf.write("output.wav", wav, model.tts_model.sample_rate)
print("saved: output.wav")

# Streaming
chunks = []
for chunk in model.generate_streaming(
    text = "Streaming text to speech is easy with VoxCPM!",
    # supports same args as above
):
    chunks.append(chunk)
wav = np.concatenate(chunks)

sf.write("output_streaming.wav", wav, model.tts_model.sample_rate)
print("saved: output_streaming.wav")
